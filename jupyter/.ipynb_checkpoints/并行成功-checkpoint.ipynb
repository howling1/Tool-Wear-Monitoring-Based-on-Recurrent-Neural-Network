# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F
from torch.nn.utils import weight_norm

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
import time 
from sklearn.manifold import TSNE

# %%
class Net(nn.Module):
    def __init__(self,filter_num,filter_size,window_size,padding,blstm_unit_num):
        super(Net, self).__init__()
       #定义CNN
        self.conv = nn.Conv1d(1, filter_num,filter_size, padding=padding, stride=1)
        self.sigmoid = nn.Sigmoid()
        self.pool = nn.MaxPool1d(window_size)
        
        #定义Bi-LSTM
        self.bl1 = nn.LSTM(input_size=1,hidden_size=blstm_unit_num,batch_first=True,bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.bl2 = nn.LSTM(input_size=100,hidden_size=blstm_unit_num,batch_first=True,bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)
        
        #定义全连接网络
        self.fc = nn.Linear(360, 512)
        self.relu = nn.ReLU()
        self.dropout3 = nn.Dropout(0.3) 
        
        #输出层
        self.outlayer = nn.Linear(512,2)
        self.softmax = nn.Softmax()

        self.padding = padding
        self.filter_size = filter_size
        self.window_size = window_size
        self.filter_num = filter_num
        self.blstm_unit_num = blstm_unit_num

    def forward(self, x ,hidden):
        # CNN运算
        # 尺寸：(batch_size, 1,信号长度=130)
        x1 = self.conv(x)
        x1 = self.sigmoid(x1)
        # 尺寸：(batch_size, filter_num, signal_length+2*padding-filter_size+1)
        x1 = self.pool(x1)
        x1 = x1.view(-1,260)

        # Bi—LSTM运算
        x2 = x.view(-1,130,1)
        hhh1 = hidden[0]
        x2, (h_n, c_n) = self.bl1(x2,hhh1)
        x2 = self.dropout1(x2)
        bl1_output = x2[:, -1, :]
        x2, (h_n, c_n) = self.bl2(x2,hhh1)
        x2 = self.dropout2(x2)
        x2 = x2[:, -1, :]
        bl2_output = x2
        
        #特征融合
        x = torch.cat((x1,x2),dim=1)
        merged_feature = x
        # 全连接网络运算
        x = self.fc(x)
        x = self.relu(x)
        x = self.dropout3(x)
        
        # 输出
        x = self.outlayer(x)
        x = self.softmax(x)
        return (x,bl1_output,bl2_output,merged_feature)

    def initHidden(self, batch_size):
        # 对隐含层单元变量全部初始化为0
        # 注意尺寸是： layer_size, batch_size, hidden_size
        out = []
        hidden1 = torch.zeros(2, batch_size, self.blstm_unit_num)
        cell1 = torch.zeros(2, batch_size, self.blstm_unit_num)
        out.append((hidden1, cell1))
        return out


def create_loader(batch_size,train_data,test_data,valid_data):
    """建立数据加载器"""
    x_train = torch.from_numpy(np.array(train_data)[:,0:-1].astype(np.float32))
    x_test = torch.from_numpy(np.array(test_data)[:, 0:-1].astype(np.float32))
    x_valid = torch.from_numpy(np.array(valid_data)[:,0:-1].astype(np.float32))

    x_train = x_train.view(-1, 1, 130)
    x_test = x_test.view(-1, 1, 130)
    x_valid = x_valid.view(-1, 1, 130)

    y_train = torch.from_numpy(np.array(pd.get_dummies(
        train_data.iloc[:, -1])).astype(np.float32))
    y_test = torch.from_numpy(np.array(pd.get_dummies(
        test_data.iloc[:, -1])).astype(np.float32))
    y_valid = torch.from_numpy(np.array(pd.get_dummies(
        valid_data.iloc[:, -1])).astype(np.float32))

    train_dataset = TensorDataset(x_train, y_train)
    test_dataset = TensorDataset(x_test, y_test)
    valid_dataset = TensorDataset(x_valid, y_valid)

    train_loader = DataLoader(dataset=train_dataset,batch_size=batch_size,shuffle=True)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size)
    valid_loader = DataLoader(dataset=valid_dataset,batch_size=batch_size,shuffle=True)

    return train_loader, test_loader, valid_loader


def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv1d') != -1:
        nn.init.xavier_uniform_(m.weight.data)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        nn.init.xavier_uniform_(m.weight.data)
        nn.init.constant_(m.bias.data, 0)


class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2, logits=False, reduce=True):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.logits = logits
        self.reduce = reduce

    def forward(self, inputs, targets):
        if self.logits:
            BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduce=False)
        else:
            BCE_loss = F.binary_cross_entropy(inputs, targets, reduce=False)
        pt = torch.exp(-BCE_loss)
        tg = torch.max(targets.data,1)[1].view(-1,1)
        F_loss = self.alpha * (1-pt)**self.gamma * BCE_loss * tg+\
                 (1-self.alpha)* (1-pt)**self.gamma * BCE_loss * (1-tg)

        if self.reduce:
            return torch.mean(F_loss)
        else:
            return F_loss


def cal_accuracy(predictions, labels):
    """calculate accuracy and the number of rightness"""
    pred = torch.max(predictions.data, 1)[1]
    lab = torch.max(labels.data, 1)[1]
    rights = pred.eq(lab.data.view_as(pred)).sum()
    return int(rights), len(labels)

def drawer(valid_loss, valid_acc, train_loss, train_acc):
    """draw train figure"""
    fig = plt.figure(figsize=(20, 8), dpi=80)
    plt.subplot(121)
    plt.plot(train_loss)
    plt.plot(valid_loss)
    plt.title('loss change')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')

    plt.subplot(122)
    plt.plot(train_acc)
    plt.plot(valid_acc)
    plt.title('accuracy change')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')

    plt.show()

# %%
if __name__ == '__main__':
    batch_size = 25
    num_classes = 2
    filter_num = 10
    filter_size = 3
    padding = 1
    window_size = 5
    blstm_unit_num = 50
    #blstm_layer_num = 2
    epochs = 30

    loss_selection = input('please select loss fuction,0 is crossentropy,1 is focal loss:')
    train_data = pd.read_csv('../data/original training data.csv')
    test_data = pd.read_csv('../data/original test data.csv')
    valid_data = pd.read_csv('../data/original valid data.csv')

    train_loader, test_loader, valid_loader = create_loader(batch_size, train_data, test_data, valid_data)
    net = Net(filter_num,filter_size,window_size,padding,blstm_unit_num)
    net.apply(weights_init)
    if loss_selection == '0':
        criterion = nn.BCELoss()
    elif loss_selection == '1':
        criterion = FocalLoss()
    optimizer = optim.Adam(net.parameters(), lr=0.001)
    train_losses = []
    train_accuracies = []
    valid_losses = []
    valid_accuracies = []

    # train model
    starttime = time.time() 
    for epoch in range(epochs):
        train_rights = 0
        train_num = 0
        train_loss_sum = 0
        for batch, data in enumerate(train_loader):
            x, y = Variable(data[0],requires_grad = True),Variable(data[1])
            net.train()
            init_hidden = net.initHidden(len(data[0]))  # 初始化LSTM的隐单元变量
            output = net(x,init_hidden)[0]
            loss = criterion(output, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            rights, num = cal_accuracy(output, y)
            train_rights += rights
            train_num += num
            train_loss_sum += float(loss) * len(data[0])

        train_accuracy = train_rights/train_num
        train_loss = train_loss_sum/train_num
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)

        if 0 == 0:
            # Run over the check set and calculate the classification accuracy
            # on the check set
            valid_rights = 0
            valid_num = 0
            valid_loss_sum = 0
            net.eval()
            for batch, data in enumerate(valid_loader):
                init_hidden = net.initHidden(len(data[0]))
                x, y = Variable(data[0]), Variable(data[1])
                output = net(x,init_hidden)[0]
                loss = criterion(output, y)
                rights, num = cal_accuracy(output, y)
                valid_rights += rights
                valid_num += num
                valid_loss_sum += float(loss)*len(data[0])

            valid_accuracy = valid_rights/valid_num
            valid_loss = valid_loss_sum/valid_num
            valid_losses.append(valid_loss)
            valid_accuracies.append(valid_accuracy)

            print(
                '第{}轮, 训练Loss:{:.10f}, 训练准确度:{:.4f},校验Loss:{:.10f}, 校验准确度:{:.4f}'.format(
                    epoch,
                    train_loss,
                    train_accuracy,
                    valid_loss,
                    valid_accuracy))
    
    endtime = time.time()
    dtime = endtime - starttime
    print("训练时间:",dtime,'s')
    
    # Run on the test set and calculate the total accuracy
    net.eval()
    test_rights = 0
    test_num = 0
    i = 0 

    for batch, data in enumerate(test_loader):
        init_hidden = net.initHidden(len(data[0]))
        x, y = Variable(data[0]),Variable(data[1])
        output = net(x,init_hidden)
        test_bl_output = output[1:]
        test_merged_feature = output[-1]
        output = output[0]
        rights,num = cal_accuracy(output, y)
        test_rights+=rights
        test_num+=num
        if i==0:
            test_true = y.detach().numpy()
            test_pre = output.detach().numpy()
            bl1_output = test_bl_output[0].detach().numpy()
            bl2_output = test_bl_output[1].detach().numpy()
            test_merged_features = test_merged_feature.detach().numpy()
        else:
            test_true = np.vstack((test_true,y.detach().numpy())) 
            test_pre = np.vstack((test_pre,output.detach().numpy()))
            bl1_output = np.vstack((bl1_output,test_bl_output[0].detach().numpy()))
            bl2_output = np.vstack((bl2_output,test_bl_output[1].detach().numpy())) 
            test_merged_features = np.vstack((test_merged_features,test_merged_feature.detach().numpy()))
        i+=1

    test_accuracy = test_rights/test_num
    print('测试集准确率:', test_accuracy)
    print("LSTM模型的AUC指标：", roc_auc_score(test_true, test_pre))
    drawer(valid_losses,valid_accuracies,train_losses,train_accuracies)
    
    
    


    # # save the model
    # if loss_selection == '0':
    #     torch.save(
    #         net, 'model/convolution BiLSTM model based on crossentropy.pkl')
    # elif loss_selection == '1':
    #     torch.save(net, 'model/convolution BiLSTM model based focal loss.pkl')

    # load model
    # model = torch.load(PATH)
    # model.eval()
# Out:
# please select loss fuction,0 is crossentropy,1 is focal loss:1
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:60: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 第0轮, 训练Loss:0.0289862663, 训练准确度:0.9870,校验Loss:0.0198271580, 校验准确度:0.9888
# 第1轮, 训练Loss:0.0107147780, 训练准确度:0.9888,校验Loss:0.0064488718, 校验准确度:0.9888
# 第2轮, 训练Loss:0.0092029494, 训练准确度:0.9888,校验Loss:0.0062513480, 校验准确度:0.9888
# 第3轮, 训练Loss:0.0041400868, 训练准确度:0.9888,校验Loss:0.0041814177, 校验准确度:0.9888
# 第4轮, 训练Loss:0.0032980116, 训练准确度:0.9907,校验Loss:0.0024981143, 校验准确度:0.9944
# 第5轮, 训练Loss:0.0008386554, 训练准确度:0.9981,校验Loss:0.0001612369, 校验准确度:1.0000
# 第6轮, 训练Loss:0.0000106051, 训练准确度:1.0000,校验Loss:0.0004050205, 校验准确度:1.0000
# 第7轮, 训练Loss:0.0000036629, 训练准确度:1.0000,校验Loss:0.0000021751, 校验准确度:1.0000
# 第8轮, 训练Loss:0.0000011079, 训练准确度:1.0000,校验Loss:0.0000020815, 校验准确度:1.0000
# 第9轮, 训练Loss:0.0000002010, 训练准确度:1.0000,校验Loss:0.0000005538, 校验准确度:1.0000
# 第10轮, 训练Loss:0.0000002231, 训练准确度:1.0000,校验Loss:0.0000002353, 校验准确度:1.0000
# 第11轮, 训练Loss:0.0000001234, 训练准确度:1.0000,校验Loss:0.0000001899, 校验准确度:1.0000
# 第12轮, 训练Loss:0.0000002972, 训练准确度:1.0000,校验Loss:0.0000000665, 校验准确度:1.0000
# 第13轮, 训练Loss:0.0000002356, 训练准确度:1.0000,校验Loss:0.0000002317, 校验准确度:1.0000
# 第14轮, 训练Loss:0.0000000461, 训练准确度:1.0000,校验Loss:0.0000000912, 校验准确度:1.0000
# 第15轮, 训练Loss:0.0000001029, 训练准确度:1.0000,校验Loss:0.0000000445, 校验准确度:1.0000
# 第16轮, 训练Loss:0.0000000269, 训练准确度:1.0000,校验Loss:0.0000000200, 校验准确度:1.0000
# 第17轮, 训练Loss:0.0000000217, 训练准确度:1.0000,校验Loss:0.0000000271, 校验准确度:1.0000
# 第18轮, 训练Loss:0.0000002461, 训练准确度:1.0000,校验Loss:0.0000000043, 校验准确度:1.0000
# 第19轮, 训练Loss:0.0000003028, 训练准确度:1.0000,校验Loss:0.0000000048, 校验准确度:1.0000
# 第20轮, 训练Loss:0.0000000176, 训练准确度:1.0000,校验Loss:0.0000000094, 校验准确度:1.0000
# 第21轮, 训练Loss:0.0000000608, 训练准确度:1.0000,校验Loss:0.0000000040, 校验准确度:1.0000
# 第22轮, 训练Loss:0.0000000448, 训练准确度:1.0000,校验Loss:0.0000000033, 校验准确度:1.0000
# 第23轮, 训练Loss:0.0000000075, 训练准确度:1.0000,校验Loss:0.0000000043, 校验准确度:1.0000
# 第24轮, 训练Loss:0.0000000140, 训练准确度:1.0000,校验Loss:0.0000000033, 校验准确度:1.0000
# 第25轮, 训练Loss:0.0000000162, 训练准确度:1.0000,校验Loss:0.0000000034, 校验准确度:1.0000
# 第26轮, 训练Loss:0.0000000090, 训练准确度:1.0000,校验Loss:0.0000000034, 校验准确度:1.0000
# 第27轮, 训练Loss:0.0000000381, 训练准确度:1.0000,校验Loss:0.0000000034, 校验准确度:1.0000
# 第28轮, 训练Loss:0.0000000104, 训练准确度:1.0000,校验Loss:0.0000000034, 校验准确度:1.0000
# 第29轮, 训练Loss:0.0000000061, 训练准确度:1.0000,校验Loss:0.0000000035, 校验准确度:1.0000
# 训练时间: 137.67458200454712 s
# 测试集准确率: 1.0
# LSTM模型的AUC指标： 1.0

# %%
test_true_1d = [np.argmax(i) for i in test_true]

# %%
ts1 = TSNE(n_components=2,init='pca', random_state=1)
ts1.fit_transform(bl1_output)
data_2d = ts1.embedding_

# %%
d1 = []
d2 = []
label = []

for i in data_2d:
    x = i[0]
    y = i[1]
    d1.append(x)
    d2.append(y)
    
label = list(test_true_1d) 

fig = plt.figure(figsize=(20, 8), dpi=80)
plt.scatter(d1,d2,c=label)
plt.title("Bi-LSTM1",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Bi-LSTM1')

# %%
ts2 = TSNE(n_components=2,init='pca', random_state=1)
ts2.fit_transform(bl2_output)
data_2d = ts2.embedding_

# %%
d1 = []
d2 = []
label = []

for i in data_2d:
    x = i[0]
    y = i[1]
    d1.append(x)
    d2.append(y)
    
label = list(test_true_1d) 

fig = plt.figure(figsize=(20, 8), dpi=80)
plt.scatter(d1,d2,c=label)
plt.title("Bi-LSTM2",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Bi-LSTM2')

# %%
ts3 = TSNE(n_components=2,init='pca', random_state=1)
ts3.fit_transform(test_merged_features)
data_2d = ts3.embedding_

# %%
d1 = []
d2 = []
label = []

for i in data_2d:
    x = i[0]
    y = i[1]
    d1.append(x)
    d2.append(y)
    
label = list(test_true_1d) 

fig = plt.figure(figsize=(20, 8), dpi=80)
plt.scatter(d1,d2,c=label)
plt.title("merge with CNN",fontsize=15)
# Out:
# Text(0.5, 1.0, 'merge with CNN')
